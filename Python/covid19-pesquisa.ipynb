# %%
import numpy as np
import pandas as pd
import os 
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
import matplotlib.pyplot
import plotly.express as px
import seaborn as sns
import plotly.express as px
# Out:
# /kaggle/input/casos-covid19/obito_cartorio.csv
# /kaggle/input/casos-covid19/caso_full.csv
# /kaggle/input/casos-covid19/caso.csv
# /kaggle/input/casos-covid19/boletim.csv

# %%
print(os.getcwd())
# Out:
# /kaggle/working

# %%
print(os.listdir('..'))
# Out:
# ['lib', 'input', 'working']

# %%
print(os.listdir('../input/casos-covid19/'))
# Out:
# ['obito_cartorio.csv', 'caso_full.csv', 'caso.csv', 'boletim.csv']

# %%
boletim = pd.read_csv('../input/casos-covid19/boletim.csv')

# %%
print(type(boletim))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
boletim
# Out:
#              date notes state  \
# 0      2020-03-16   NaN    AP
# 1      2020-03-17   NaN    AP
# 2      2020-03-18   NaN    AP
# 3      2020-03-19   NaN    AP
# 4      2020-03-20   NaN    AP
# ...           ...   ...   ...
# 20822  2020-05-04   NaN    SP
# 20823  2020-05-03   NaN    SP
# 20824  2020-05-02   NaN    SP
# 20825  2020-05-01   NaN    SP
# 20826  2020-04-30   NaN    SP
#
#                                                      url
# 0      https://www.portal.ap.gov.br/noticia/1603/bole...
# 1      https://www.portal.ap.gov.br/noticia/1703/bole...
# 2      https://www.portal.ap.gov.br/noticia/1803/bole...
# 3      https://www.portal.ap.gov.br/noticia/1903/bole...
# 4      https://www.portal.ap.gov.br/noticia/2003/bole...
# ...                                                  ...
# 20822  http://www.saude.sp.gov.br/resources/cve-centr...
# 20823  http://www.saude.sp.gov.br/resources/cve-centr...
# 20824  http://www.saude.sp.gov.br/resources/cve-centr...
# ...

# %%
casos = pd.read_csv('../input/casos-covid19/caso.csv')

# %%
print(type(casos))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
casos
# Out:
#                date state  city place_type  confirmed  deaths  \
# 0        2022-03-27    AP   NaN      state     160328    2122
# 1        2022-03-26    AP   NaN      state     160321    2122
# 2        2022-03-25    AP   NaN      state     160314    2122
# 3        2022-03-24    AP   NaN      state     160301    2122
# 4        2022-03-23    AP   NaN      state     160288    2122
# ...             ...   ...   ...        ...        ...     ...
# 2837998  2020-06-23    SP  Óleo       city          1       0
# 2837999  2020-06-22    SP  Óleo       city          1       0
# 2838000  2020-06-21    SP  Óleo       city          1       0
# 2838001  2020-06-20    SP  Óleo       city          1       0
# 2838002  2020-06-19    SP  Óleo       city          1       0
#
#          order_for_place  is_last  estimated_population_2019  \
# 0                    734     True                   845731.0
# 1                    733    False                   845731.0
# ...

# %%
casosf = pd.read_csv('../input/casos-covid19/caso_full.csv')

# %%
print(type(casosf))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
casosf
# Out:
#                  city  city_ibge_code        date  epidemiological_week  \
# 0          Rio Branco       1200401.0  2020-03-17                202012
# 1                 NaN            12.0  2020-03-17                202012
# 2          Rio Branco       1200401.0  2020-03-18                202012
# 3                 NaN            12.0  2020-03-18                202012
# 4          Rio Branco       1200401.0  2020-03-19                202012
# ...               ...             ...         ...                   ...
# 3853643      Tupirama       1721257.0  2022-03-27                202213
# 3853644    Tupiratins       1721307.0  2022-03-27                202213
# 3853645  Wanderlândia       1722081.0  2022-03-27                202213
# 3853646       Xambioá       1722107.0  2022-03-27                202213
# 3853647           NaN            17.0  2022-03-27                202213
#
#          estimated_population  estimated_population_2019  is_last  \
# ...

# %%
obito = pd.read_csv('../input/casos-covid19/obito_cartorio.csv')

# %%
print(type(obito))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
obito
# Out:
#             date state  epidemiological_week_2019  epidemiological_week_2020  \
# 0     2020-01-01    AC                          1                          1
# 1     2020-01-02    AC                          1                          1
# 2     2020-01-03    AC                          1                          1
# 3     2020-01-04    AC                          1                          1
# 4     2020-01-05    AC                          1                          2
# ...          ...   ...                        ...                        ...
# 9877  2020-12-27    TO                         52                         53
# 9878  2020-12-28    TO                         52                         53
# 9879  2020-12-29    TO                          1                         53
# 9880  2020-12-30    TO                          1                         53
# 9881  2020-12-31    TO                          1                         53
#
# ...

# %%
obito.describe()
# Out:
#        epidemiological_week_2019  epidemiological_week_2020  \
# count                9882.000000                9882.000000
# mean                   26.382514                  27.071038
# std                    15.054622                  15.098999
# min                     1.000000                   1.000000
# 25%                    13.000000                  14.000000
# 50%                    26.000000                  27.000000
# 75%                    39.000000                  40.000000
# max                    52.000000                  53.000000
#
#        deaths_indeterminate_2019  deaths_respiratory_failure_2019  \
# count                9882.000000                      9882.000000
# mean                  124.642785                      1850.454361
# std                   251.787453                      3194.941627
# min                     0.000000                         0.000000
# 25%                    15.000000                       244.000000
# ...

# %%
casos.describe()
# Out:
#           confirmed        deaths  order_for_place  estimated_population_2019  \
# count  2.838003e+06  2.838003e+06     2.838003e+06               2.827618e+06
# mean   5.149393e+03  1.379947e+02     2.618823e+02               9.466038e+04
# std    7.020509e+04  2.131838e+03     1.598804e+02               1.029041e+06
# min    0.000000e+00  0.000000e+00     1.000000e+00               7.810000e+02
# 25%    9.200000e+01  2.000000e+00     1.270000e+02               5.536000e+03
# 50%    3.580000e+02  7.000000e+00     2.530000e+02               1.213000e+04
# 75%    1.103000e+03  2.300000e+01     3.850000e+02               2.704700e+04
# max    5.232374e+06  1.671100e+05     7.500000e+02               4.591905e+07
#
#        estimated_population  city_ibge_code  confirmed_per_100k_inhabitants  \
# count          2.827618e+06    2.827618e+06                    2.813528e+06
# mean           9.539192e+04    3.261214e+06                    4.958568e+03
# ...

# %%
casosf.describe()
# Out:
#        city_ibge_code  epidemiological_week  estimated_population  \
# count    3.840002e+06          3.853648e+06          3.840002e+06
# mean     3.228321e+06          2.021052e+05          8.116488e+04
# std      1.009499e+06          5.755437e+01          9.057809e+05
# min      1.100000e+01          2.020090e+05          7.760000e+02
# 25%      2.509107e+06          2.020440e+05          5.602000e+03
# 50%      3.144508e+06          2.021160e+05          1.219500e+04
# 75%      4.117297e+06          2.021400e+05          2.689900e+04
# max      5.300108e+06          2.022130e+05          4.628933e+07
#
#        estimated_population_2019  last_available_confirmed  \
# count               3.840002e+06              3.853648e+06
# mean                8.054619e+04              4.777532e+03
# std                 8.992380e+05              6.180363e+04
# min                 7.810000e+02              0.000000e+00
# 25%                 5.603000e+03              1.420000e+02
# ...

# %%
boletim.describe()
# Out:
#               date                                              notes  state  \
# count        20827                                               6565  20827
# unique         787                                               1630     27
# top     2020-04-04  Dados totais coletados da Secretaria Estadual ...     GO
# freq            37                                               4123    945
#
#                                                       url
# count                                               20827
# unique                                              10832
# top     https://docs.google.com/spreadsheets/d/17mmfgP...
# freq                                                 4123

# %%
obito['date']
# Out:
# 0       2020-01-01
# 1       2020-01-02
# 2       2020-01-03
# 3       2020-01-04
# 4       2020-01-05
#            ...
# 9877    2020-12-27
# 9878    2020-12-28
# 9879    2020-12-29
# 9880    2020-12-30
# 9881    2020-12-31
# Name: date, Length: 9882, dtype: object

# %%
obdate = obito['date']

# %%
obdate
# Out:
# 0       2020-01-01
# 1       2020-01-02
# 2       2020-01-03
# 3       2020-01-04
# 4       2020-01-05
#            ...
# 9877    2020-12-27
# 9878    2020-12-28
# 9879    2020-12-29
# 9880    2020-12-30
# 9881    2020-12-31
# Name: date, Length: 9882, dtype: object
